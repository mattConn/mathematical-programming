# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

file = open("../sum-consecutive-integers_10^6.txt","r")

MAX = 10**6

x = np.arange(1,MAX+1)
l = [] #list of sums

for line in iter(file):
    l.append(line)

plt.plot(x,l,'b')
plt.plot(x,x**2,'r')
# Out:
# <img src="data:image/png;base64,...">
