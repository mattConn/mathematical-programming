# %%
using Plots, Calculus
plotly()
f(x) = x*log(x)-x
# f' is equal to nat. log of x
plot([zero,f,f'],0,5)
# Out:
# <script src="file:///Users/matthew/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="30d37548-15fc-4a36-b700-d25148f712bd" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('30d37548-15fc-4a36-b700-d25148f712bd');
# ...
