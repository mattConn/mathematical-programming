# %%
# %matplotlib notebook

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

MAX = 10**6

ymin = 2.6
ymax = 3.5
xmin = 0
xmax = 50

plt.grid()
plt.ylim(ymin,ymax)
plt.xlim(xmin,xmax)

file = open("../approximating_pi/gregory-leibniz-series_10^6.txt","r")

x = np.arange(1,10**6+1)
l = [] #list of pi approximations

for line in iter(file):
    l.append(line)

file.close()

plt.plot(x,l,'bo-')
plt.axhline(y = np.pi, color='r')
# Out:
# <img src="data:image/png;base64,...">
