# %%
from sympy import *
from sympy.plotting import *
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (16,12)

u,v = symbols('u v')

def r(t):
    return t

plot3d_parametric_surface(r(v)*cos(u), r(v)*sin(u),5*u, (u, -5, 5), (v, -5, 5))
