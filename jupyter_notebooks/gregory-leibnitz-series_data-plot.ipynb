# %%
# %matplotlib notebook

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.grid()
plt.ylim(2,4)
plt.xlim(5,10)

file = open("approximating_pi/gregory-leibnitz-series_10^6.txt","r")

x = np.arange(1,10**6+1)
l = []

for line in iter(file):
    l.append(line)

file.close()

plt.plot(x,l,'bo-')
# Out:
# <img src="data:image/png;base64,...">
